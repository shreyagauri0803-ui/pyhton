# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyagauri0803-ui/pyhton/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="vrinda"
name[0]
# Out:
# 'v'

# %%
name="rajupaisalaya"
name[4:9]
# Out:
# 'paisa'

# %%
name="shreya"
name[3]
# Out:
# 'e'

# %%
name="tunemeragoldenwalachashmabecha"
name[8:14]
# Out:
# 'golden'

# %%
name="tunemeragoldenwalachashmabecha"
name[8:25]
# Out:
# 'goldenwalachashma'

# %%
name="paisalaya"
name[-1]
# Out:
# 'a'

# %%
name="abcd"
name[1:]
name[:3]
# Out:
# 'abc'

# %%
#x="mainhoonkon"(hoon)
#x="kaiseho"(ise)
#x="kabhikabhi"(kabhi)
#x="humihumhai"(humhai)
#x="oyerajn"(era)

# %%
name="mainhoonkon"
name[4:8]
# Out:
# 'hoon'

# %%
name="kaiseho"
name[2:5]
# Out:
# 'ise'

# %%
name="kabhi;kabhi"
name[:5]
# Out:
# 'kabhi'

# %%
name="humhihumhai"
name[5:]
# Out:
# 'humhai'

# %%
x="mainhoonkoon"
y="k"
if "k" in x:
  print("avalaible")
else:
  print("not avalaible")
# Out:
# avalaible

# %%
name="chintu"
name[::-2]
# Out:
# 'unh'

# %%
name="shreya"
name[::-1]
# Out:
# 'ayerhs'

# %%
name="chintu"
name[-3:]
# Out:
# 'ntu'

# %%
x="kaiseho"
for i in x:
  print(i)
# Out:
# k
# a
# i
# s
# e
# h
# o

# %%
x="name"
for i in x:
  print(i)
# Out:
# n
# a
# m
# e

# %%
x="shreya"
for i in x:
  print(i)
# Out:
# s
# h
# r
# e
# y
# a

# %%
x="kaiseho"
for i in range(len(x)):
  print(x[i])
# Out:
# k
# a
# i
# s
# e
# h
# o

# %%
x="shreya"
for i in range(len(x)):
  print(x[i])
# Out:
# s
# h
# r
# e
# y
# a

# %%
x="hello"
for i in range(len(x)):
  print(x[i])
# Out:
# h
# e
# l
# l
# o

# %%
x="tuesday"
for i in range(len(x)):
  print(x[i])
for i in x:
  print(i)
# Out:
# t
# u
# e
# s
# d
# a
# y
# t
# u
# e
# s
# d
# a
# y

# %%
x="xyyx"
rev=x[::-1]
if rev==x:
  print("pallindrom")
else:
  print("not pallindrom")
# Out:
# pallindrom

# %%
x="abcd"
rev=x[::-1]
if rev==x:
  print("pallindrom")
else:
  print("not pallindrom")
# Out:
# not pallindrom

# %%
name="xyza"
rev=""
for char in name:
  rev=char+rev
print(rev)
# Out:
# azyx

# %%
name="shreya"
rev=""
for i in name:
  rev=i+rev
print(rev)
# Out:
# ayerhs

# %%
name="hello"
rev=""
for i in name:
  rev=i+rev
print(rev)
# Out:
# olleh
