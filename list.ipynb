# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyagauri0803-ui/pyhton/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=[5,6,7,8,9]
a[3]
# Out:
# 8

# %%
a=[5,6,7,8,9]
print(a[4])
# Out:
# 9

# %%
a=[5,6,7,8,9]
print(a)
# Out:
# [5, 6, 7, 8, 9]

# %%
a=[5,6,7,8,9]
a[0:5]
# Out:
# [5, 6, 7, 8, 9]

# %%
a=[5,6,7,8,9]
a[-5:-1]
# Out:
# [5, 6, 7, 8]

# %%
a=[5,6,7,8,9]
a[:-1]
# Out:
# [5, 6, 7, 8]

# %%
a=[5,6,7,8,9]
a.append(10)
print(a)
# Out:
# [5, 6, 7, 8, 9, 10]

# %%
b=[8,4,9]
b.append(22)
print(b)
# Out:
# [8, 4, 9, 22]

# %%
a=[200,500,400,300]
length=len(a)
sum=0
for i in range(0,length):
 sum=sum+a[i]
 print(sum)
# Out:
# 200
# 700
# 1100
# 1400

# %%
a=[200,500,400,300]
sum=0
for i in a:
  sum=sum+i
print(sum)
# Out:
# 1400

# %%
b=[100,200,300,400,500,600,700,800,900,1000]
sum=0
for i in b:
  sum=sum+i
  print(sum)
# Out:
# 100
# 300
# 600
# 1000
# 1500
# 2100
# 2800
# 3600
# 4500
# 5500

# %%
c=[200,400,600,800,1000]
sum=0
lenght=len(c)
for i in range(0,lenght):
  sum=sum+c[i]
  print(sum)
# Out:
# 200
# 600
# 1200
# 2000
# 3000

# %%
items=["pizza","burger","noodels","pasta","chips","cold drink","chocolate","ice cream","fries","coffee"]
price=[300,100,200,250,50,50,200,100,150,200]
discount=[10,25,10,30,15,20,5,10,20,30]
sum=0
length=len(price)
for i in range(0,length):
  sum=sum+price[i]
  print(sum)
# Out:
# 300
# 400
# 600
# 850
# 900
# 950
# 1150
# 1250
# 1400
# 1600
