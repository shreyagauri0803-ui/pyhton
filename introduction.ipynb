# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyagauri0803-ui/pyhton/blob/main/introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hi i am writing two mnumbe add
"""uuhgyg
jhuii jnjnuju
kjijikokook """

''' uhuh88
jhuhii
kojkoko
kookoko'''
print("my name jjj jhuighuihihiikjuihih huhuhio")
# Out:
# my name jjj jhuighuihihiikjuihih huhuhio

# %%
print("Name  :  Prince")
print("eduaction :graduate")
print("adress : 123 road")
print("email: xyz123@gmail.com")
print("contact no:123456")
print("course: python")
print("fees : 1000")
# Out:
# Name  :  Prince
# eduaction :graduate
# adress : 123 road
# email: xyz123@gmail.com
# contact no:123456
# course: python
# fees : 1000

# %%
name= "shreya"
print(name)
age =22
print(age)
print(f"my name is {name}")
print("my name is",name)
print(f"my age is {age}")
print("my age is", age )
# Out:
# shreya
# 22
# my name is shreya
# my name is shreya
# my age is 22
# my age is 22

# %%
number1=8
number2=9
sum=number1+number2
sub=number1-number2
multiply=number1*number2
divide=number1/number2
mod=number1%number2
print("the sum is",sum)
print("the sub is",sub)
print("the multiply is" ,multiply)
print("the divide is" ,divide)
print("the mod is" ,mod)
# Out:
# the sum is 17
# the sub is -1
# the multiply is 72
# the divide is 0.8888888888888888
# the mod is 8

# %%
num1=int(input("enter the first number"))
num2=int(input("enter the second number"))
sum=num1+num2
divide=num1/num2
print(divide)
print(sum)
# Out:
# enter the first number10
# enter the second number12
# 0.8333333333333334
# 22

# %%
pizza=200
burger=100
noodels=300
cold_drink=50
pasta= 400
total=pizza+burger+noodels+cold_drink+pasta
print ("my total bill is" ,total)
# Out:
# my total bill is 1050

# %%
pizza=int(input("enter the pizza price"))
burger=int(input("enter the burger price"))
noodles=int(input("enter the nooddles price"))
cold_drink=int(input("enter the cold_drink price"))
pasta=int(input("enter the pasta proce"))
total=pizza+burger+noodles+cold_drink+pasta
print("my total bill is", total)
# Out:
# enter the pizza price200
# enter the burger price100
# enter the nooddles price250
# enter the cold_drink price50
# enter the pasta proce300
# my total bill is 900

# %%
item1=(input("enter item 1: "))
price1=int(input("enter the price of itme 1: "))
discount1=int(input("enter the amount of discount of item 1 "))
dis1=price1*discount1/100
total1=price1-dis1
print("the price of itme 1 after discount is: ",total1)
item2=(input("enter itme 2: "))
price2=int(input("enter the price of item 2: "))
discount2=int(input("enter the amount of discount of item 2 "))
dis2=price2*discount2/100
total2=price2-dis2
print("price of item 2 after discount is:",total2)
item3=input("enter item 3: ")
price3=int(input("enter the price of item 3: "))
discount3=int(input("enter the amount of discount 3 "))
dis3=price3*discount3/100
total3=price3-dis3
print("price of item 3 after discount is: ",total3)
item4=(input("enter item 4: "))
price4=int(input("enter the price of item 4: "))
discount4=int(input("enter the amount of discount 4 "))
dis4=price4*discount4/100
total4=price4-dis4
print("price of itme 4 after discount is: ",total4)
total=total1+total2+total3+total4
discount=int(input("enter the total percentage of discount"))
total_discount=total*discount/100
final_amount=total-total_discount
print("my total bill is ",total)
# print(item1,item2,item3,item4)
print(" my final amount is",final_amount)
# Out:
# enter item 1: pizza
# enter the price of itme 1: 300
# enter the amount of discount of item 1 10
# the price of itme 1 after discount is:  270.0
# enter itme 2: burger
# enter the price of item 2: 200
# enter the amount of discount of item 2 5
# price of item 2 after discount is: 190.0
# enter item 3: noodles
# enter the price of item 3: 100
# enter the amount of discount 3 8
# price of item 3 after discount is:  92.0
# enter item 4: cold drink
# enter the price of item 4: 100
# enter the amount of discount 4 9
# price of itme 4 after discount is:  91.0
# enter the total percentage of discount20
# my total bill is  643.0
#  my final amount is 514.4

# %%
shopping=int(input("shopping:  "))
grocery=int(input("grocery:  "))
electricity=int(input("electricity:"))
wifi=int(input("wifi: "))
fees=int(input("fees amount: "))
phone_bill=int(input("phone_bill:"))
total=shopping+grocery+electricity+wifi+fees+phone_bill
print("my total amount is",total)
# Out:
# shopping:  1000
# grocery:  5000
# electricity:3000
# wifi: 2000
# fees amount: 7000
# phone_bill:1000
# my total amount is 19000

# %%
p=(int(input("enter pricipal")))
t=(int(input("enter time")))
r=(int(input("enter rate of interest")))
si=(p*r*t)/100
print(f"simple interest is {si}")
# Out:
# enter pricipal10000
# enter time9
# enter rate of interest7
# simple interest is 6300.0

# %%
p=int(input("enter the principal"))
t=int(input("enter the time"))
r=int(input("enter the rate of interest"))
d=int(input("enter the days"))
time=d/31+t
si=(p*r*time)/100
print(f"simple interest is {si}")
# Out:
# enter the principal20000
# enter the time3
# enter the rate of interest5
# enter the days12
# simple interest is 3387.0967741935483

# %%
num=int(input("enter the number"))
if num%2==0:
  print("even")
else:
  print("odd")
# Out:
# enter the number13
# odd

# %%
gen=(input("enter the gender "))
if gen=="male":
  print("you are male")
elif gen=="female":
  print("you are a female")
else:
  print("error")
# Out:
# enter the gender male
# you are male

# %%
num=int(input("enter the age "))
if num>=18:
  print("you are eligible for voting")
else:
  print("not eligible")
# Out:
# enter the age 22
# you are eligible for voting
