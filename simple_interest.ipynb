# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyagauri0803-ui/pyhton/blob/main/simple_interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p=int(input("enter the principal"))
r=int(input("enter the rate of interest"))
t=int(input("enter the time"))
d=int(input("enter the days"))
month=(input("enter the month"))
year=int(input("enter the year"))
if month=="january"or month=="march"or month=="may"or month=="july"or month=="august"or month=="october" or month=="december":
  days_in_month=31
elif month=="april" or month=="june" or month=="september" or month=="november":
  days_in_month=30
else:
  if year%4==0 and year%100!=0 or year%400==0:
    days_in_month=29
  else:
    days_in_month=28
time=d/days_in_month
si=(p*r*t)/100
time=d/days_in_month
si_of_days=p*r*time/100

total_si= si+si_of_days
print("simple interest is",total_si)
# Out:
# enter the principal200000
# enter the rate of interest30
# enter the time5
# enter the days60
# enter the monthmay
# enter the year4098
# simple interest is 416129.03225806454

# %%
month=(input("enter the month "))
days=int(input("enter the no of days"))
if month=="january"or month=="march" or month=="may"or month=="july" or month=="august"or month=="october"or month=="decmeber":
   days_in_month=31

elif month=="april"or month=="june"or month=="spetember" or month=="november":
  days_in_month=30
else:
  days_in_month=28
print(f"days in month is{days_in_month}")
time=days/days_in_month
print(f"total time is{time}")
# Out:
# enter the month may
# enter the no of days20
# days in month is31
# total time is0.6451612903225806

# %%
p=int(input("enter the principal"))
r=int(input("enter the interest"))
t=int(input("enter the time"))
month=(input("enter the month"))
d=int(input("enter the days"))
year=int(input("enter the year"))
if month=="january"or month=="march"or month=="may"or month=="july"or month=="august"or month=="october"or month=="december":
 days_in_month=31
elif month=="april"or month=="june"or month=="september"or month=="november":
  days_in_month=30
else:
  if year%4==0 and year%100!=0 or year%400==0:
    days_in_month=29
  else:
    days_in_month=28
time=d/days_in_month
si=(p*r*t)/100
time=d/days_in_month
si_days=(p*r*time)/100
total_si=si+si_days
print("simple interest is",total_si)
# Out:
# enter the principal1000
# enter the interest12
# enter the time12
# enter the monthmarch
# enter the days12
# enter the year1212
# simple interest is 1486.4516129032259

# %%
p=int(input("eneter the principal"))
r=int(input("enter the rate of interest"))
t=int(input("enter the time"))
d=int(input("enter the days"))

si=(p*r*t)/100
time=d/days_in_month
si_of_days=p*r*time/100

total_si= si+si_of_days

print("simple interest is", si)
# Out:
# eneter the principal1000
# enter the rate of interest2
# enter the time5
# enter the days20
# simple interest is 100.0

# %%
p=int(input("enter the principal"))
r=int(input("enter the interest"))
t=int(input("enter the time"))
m=(input("enter the month"))
d=int(input("enter the days"))
y=int(input("enter the year"))
if m.lower()=="january"or m.lower()=="march"or m.lower()=="may"or m.lower()=="july"or m.lower()=="august"or m.lower()=="october"or m.lower()=="december":
  days_in_month=31
elif m.lower()=="april"or m.lower()=="june"or m.lower()=="september"or m.lower()=="november":
  days_in_month=30
else:
   if y%4==0 and y%100!=0 or y%400==0:
     days_in_month=29
   else:
     days_in_month=28
time=d/days_in_month
si=(p*r*t)/100
si_of_days=(p*r*time)/100
total_si=si_of_days+si
print("my simple interest is ",total_si)
# Out:
# enter the principal20000
# enter the interest30
# enter the time6
# enter the monthjune
# enter the days40
# enter the year3098
# my simple interest is  44000.0

# %%
p=int(input("enter the principal"))
r=int(input("enter the interest"))
d=int(input("enter the days"))
t=int(input("enter the time"))
m=(input("enter the month"))
y=int(input("enter the year"))
if month=="janauary"or month=="march"or month=="may"or month=="july"or month=="august"or month=="october"or month=="december":
   days_in_month=31
elif month=="april"or month=="june"or month=="september"or month=="november":
   days_in_month=30
else:
  if year%4==0 and year%100!=0 or year%400==0:
    days_in_month=29
  else:
    days_in_month=28
time=d/days_in_month
si=(p*r*t)/100
si_for_days=(p*r*time)/100
total_si=si+si_for_days
print("total si is",total_si)
# Out:
# enter the principal10000
# enter the interest20
# enter the days20
# enter the time5
# enter the monthmay
# enter the year3098
# total si is 11290.322580645161

# %%
p=int(input("enter the principal "))
r=int(input("enter the interest "))
t=int(input("enter the time "))
m=(input("enter the month "))
d=int(input("enter the days"))
y=int(input("enter the year"))
if month=="january"or month=="march"or month=="may"or month=="july"or month=="august"or month=="october"or month=="december":
   days_in_month=31
elif month=="april"or month=="june"or month=="september"or month=="november":
     days_in_month=30
else:
   if year%4==0 and year%100!=0 or year%400==0:
     days_in_month=29
   else:
     days_in_month=28
time=d/days_in_month
si=(p*r*t)/100
si_for_days=(p*r*time)/100
total_si=si_for_days+si
print("total si is",total_si)
# Out:
# enter the principal 40000
# enter the interest 70
# enter the time 6

# %%
p=int(input("enter the principal "))
r=int(input("enter the interst "))
t=int(input("enter the time "))
d=int(input("days in month"))
m=(input("enter the month"))
y=int(input("enter the year"))
if month=="januaury" or month=="march"or month=="may"or month=="july"or month=="august"or month=="october"or month=="december":
  days_in_month=31
elif month=="april"or month=="june"or month=="september"or month=="november":
  days_in_month=30
else:
  if year%4==0 and year%100!=0 or year%400==0:
    days_in_month=29
  else:
    days_in_month=28
time=d/days_in_month
si=(p*r*t)/100
si_for_days=p*r*time/100
total_si=si+si_for_days
print("total si is ", total_si)
# Out:
# enter the principal 8
# enter the interst 9
# enter the time 9
# days in month9
# enter the monthmay
# enter the year2025
# total si is  6.6890322580645165
